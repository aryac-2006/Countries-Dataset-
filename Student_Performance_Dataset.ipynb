# %% [markdown]
# <a href="https://colab.research.google.com/github/aryac-2006/Countries-Dataset-/blob/main/Student_Performance_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-edda4689-36c8-4247-9935-f85913fc6204" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edda4689-36c8-4247-9935-f85913fc6204">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = "/content/Student_Performance_Dataset.csv"

# %%
df = pd.read_csv(filepath)

# %%
print("<<<<< Complete Dataset >>>>>\n")
df
# Out:
# <<<<< Complete Dataset >>>>>
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 0         S0001   15    Male     12                  1.0
# 1         S0002   19  Female      9                  1.6
# 2         S0003   14  Female     12                  3.6
# 3         S0004   18  Female      9                  5.5
# 4         S0005   14    Male     10                  5.0
# ...         ...  ...     ...    ...                  ...
# 4995      S4996   17    Male     11                  4.0
# 4996      S4997   19    Male     10                  5.6
# 4997      S4998   16  Female      9                  2.3
# 4998      S4999   15    Male     11                  2.9
# 4999      S5000   19  Female     10                  2.0
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 0                        65       Postgraduate              No
# 1                        58           Graduate              No
# ...

# %%
print("<<<<< First five rows >>>>>:\n")
df.head()
# Out:
# <<<<< First five rows >>>>>:
#   Student_ID  Age  Gender  Class  Study_Hours_Per_Day  Attendance_Percentage  \
# 0      S0001   15    Male     12                  1.0                     65
# 1      S0002   19  Female      9                  1.6                     58
# 2      S0003   14  Female     12                  3.6                     64
# 3      S0004   18  Female      9                  5.5                     68
# 4      S0005   14    Male     10                  5.0                     80
#
#   Parental_Education Internet_Access Extracurricular_Activities  Math_Score  \
# 0       Postgraduate              No                         No          40
# 1           Graduate              No                        Yes          80
# 2        High School             Yes                        Yes          83
# 3       Postgraduate             Yes                         No          68
# 4        High School             Yes                         No          41
#
# ...

# %%
print("<<<<< Last five rows >>>>>:\n")
df.tail()
# Out:
# <<<<< Last five rows >>>>>:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 4995      S4996   17    Male     11                  4.0
# 4996      S4997   19    Male     10                  5.6
# 4997      S4998   16  Female      9                  2.3
# 4998      S4999   15    Male     11                  2.9
# 4999      S5000   19  Female     10                  2.0
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 4995                     50           Graduate              No
# 4996                     90        High School             Yes
# 4997                     61           Graduate              No
# 4998                     82           Graduate              No
# 4999                     97       Postgraduate              No
#
#      Extracurricular_Activities  Math_Score  Science_Score  English_Score  \
# 4995                         No          64             60             70
# ...

# %%
print("Shape of Dataset:- ")
df.shape
# Out:
# Shape of Dataset:-
# (5000, 16)

# %%
print("<<<<< COlumn Names >>>>>\n")
df.columns
# Out:
# <<<<< COlumn Names >>>>>
# Index(['Student_ID', 'Age', 'Gender', 'Class', 'Study_Hours_Per_Day',
#        'Attendance_Percentage', 'Parental_Education', 'Internet_Access',
#        'Extracurricular_Activities', 'Math_Score', 'Science_Score',
#        'English_Score', 'Previous_Year_Score', 'Final_Percentage',
#        'Performance_Level', 'Pass_Fail'],
#       dtype='object')

# %%
print("----Dataset Information----\n")
df.info()
# Out:
# ----Dataset Information----
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   Age                         5000 non-null   int64
#  2   Gender                      5000 non-null   object
#  3   Class                       5000 non-null   int64
#  4   Study_Hours_Per_Day         5000 non-null   float64
#  5   Attendance_Percentage       5000 non-null   int64
#  6   Parental_Education          5000 non-null   object
#  7   Internet_Access             5000 non-null   object
#  8   Extracurricular_Activities  5000 non-null   object
#  9   Math_Score                  5000 non-null   int64
#  10  Science_Score               5000 non-null   int64
#  11  English_Score               5000 non-null   int64
# ...

# %%
print("Statistical Information:- \n")
df.describe()
# Out:
# Statistical Information:-
#                Age        Class  Study_Hours_Per_Day  Attendance_Percentage  \
# count  5000.000000  5000.000000          5000.000000            5000.000000
# mean     16.508800    10.496400             3.287260              74.919800
# std       1.718637     1.106812             1.587979              14.673842
# min      14.000000     9.000000             0.500000              50.000000
# 25%      15.000000    10.000000             1.900000              62.000000
# 50%      17.000000    10.000000             3.300000              75.000000
# 75%      18.000000    11.000000             4.700000              88.000000
# max      19.000000    12.000000             6.000000             100.000000
#
#         Math_Score  Science_Score  English_Score  Previous_Year_Score  \
# count  5000.000000    5000.000000    5000.000000          5000.000000
# mean     67.754800      66.895400      67.782800            67.282200
# ...

# %%
print("Data Types:\n")
df.dtypes
# Out:
# Data Types:
# Student_ID                     object
# Age                             int64
# Gender                         object
# Class                           int64
# Study_Hours_Per_Day           float64
# Attendance_Percentage           int64
# Parental_Education             object
# Internet_Access                object
# Extracurricular_Activities     object
# Math_Score                      int64
# Science_Score                   int64
# English_Score                   int64
# Previous_Year_Score             int64
# Final_Percentage              float64
# Performance_Level              object
# Pass_Fail                      object
# dtype: object

# %%
print("Missing values:- \n")
df.isnull().sum()
# Out:
# Missing values:-
# Student_ID                    0
# Age                           0
# Gender                        0
# Class                         0
# Study_Hours_Per_Day           0
# Attendance_Percentage         0
# Parental_Education            0
# Internet_Access               0
# Extracurricular_Activities    0
# Math_Score                    0
# Science_Score                 0
# English_Score                 0
# Previous_Year_Score           0
# Final_Percentage              0
# Performance_Level             0
# Pass_Fail                     0
# dtype: int64

# %%
print("Unique values in each column:- \n")
df.nunique()
# Out:
# Unique values in each column:-
# Student_ID                    5000
# Age                              6
# Gender                           2
# Class                            4
# Study_Hours_Per_Day             56
# Attendance_Percentage           51
# Parental_Education               3
# Internet_Access                  2
# Extracurricular_Activities       2
# Math_Score                      66
# Science_Score                   66
# English_Score                   66
# Previous_Year_Score             56
# Final_Percentage               181
# Performance_Level                4
# Pass_Fail                        2
# dtype: int64

# %%
print("Sample of 5 random rows:")
df.sample(5)
# Out:
# Sample of 5 random rows:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 1801      S1802   18    Male     10                  2.1
# 3389      S3390   17    Male     11                  5.4
# 289       S0290   14    Male     10                  4.8
# 974       S0975   14  Female     10                  3.0
# 4970      S4971   17  Female      9                  4.2
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 1801                     53           Graduate             Yes
# 3389                     73       Postgraduate             Yes
# 289                      60       Postgraduate              No
# 974                      74           Graduate             Yes
# 4970                     88        High School              No
#
#      Extracurricular_Activities  Math_Score  Science_Score  English_Score  \
# 1801                        Yes          75             78             90
# ...

# %%
print("Gender count:\n")
df['Gender'].value_counts()
# Out:
# Gender count:
# Gender
# Female    2553
# Male      2447
# Name: count, dtype: int64

# %%
print("Averange Final Percentage:-\n")
print(df["Final_Percentage"].mean())
# Out:
# Averange Final Percentage:-
#
# 67.47765600000001

# %%
print("Highest Final Percentage:-\n")
print(df["Final_Percentage"].max())
# Out:
# Highest Final Percentage:-
#
# 98.33

# %%
print("Lowest Final Percentage:-\n")
print(df["Final_Percentage"].min())
# Out:
# Lowest Final Percentage:-
#
# 36.33

# %%
print("Student with Final Percentage greater than 90 :-\n")
print(df[df["Final_Percentage"] > 90] [["Student_ID", "Gender", "Final_Percentage"]])
# Out:
# Student with Final Percentage greater than 90 :-
#
#      Student_ID  Gender  Final_Percentage
# 21        S0022    Male             98.33
# 128       S0129  Female             90.67
# 144       S0145    Male             93.00
# 328       S0329  Female             91.33
# 405       S0406  Female             90.33
# ...         ...     ...               ...
# 4701      S4702    Male             93.00
# 4755      S4756    Male             92.33
# 4808      S4809  Female             95.33
# 4854      S4855    Male             93.67
# 4990      S4991  Female             93.67
#
# [77 rows x 3 columns]

# %%
print("Count of Total no. of students failed :-")
print(df[df["Pass_Fail"] == "Fail"].shape[0])
print("---------------------------------------")

print("\nStudents Who Failed :-")
print(df[df["Pass_Fail"] == "Fail"] [["Student_ID", "Gender", "Pass_Fail"]])
# Out:
# Count of Total no. of students failed :-
# 265
# ---------------------------------------
#
# Students Who Failed :-
#      Student_ID  Gender Pass_Fail
# 4         S0005    Male      Fail
# 27        S0028    Male      Fail
# 82        S0083    Male      Fail
# 84        S0085  Female      Fail
# 97        S0098  Female      Fail
# ...         ...     ...       ...
# 4959      S4960  Female      Fail
# 4967      S4968  Female      Fail
# 4983      S4984    Male      Fail
# 4993      S4994    Male      Fail
# 4996      S4997    Male      Fail
#
# [265 rows x 3 columns]

# %%
print("Top 10 student by Final Percentage :-\n")
df.sort_values(by = "Final_Percentage", ascending = False).head(10)
# Out:
# Top 10 student by Final Percentage :-
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 21        S0022   15    Male     12                  2.8
# 3636      S3637   15  Female      9                  3.8
# 3748      S3749   17    Male     11                  0.5
# 2211      S2212   19    Male     11                  1.8
# 1599      S1600   14    Male      9                  5.0
# 4244      S4245   17  Female     12                  1.3
# 2196      S2197   14  Female     11                  1.7
# 4504      S4505   14  Female     11                  1.1
# 1968      S1969   17    Male     12                  5.4
# 3269      S3270   17  Female      9                  5.2
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 21                       83       Postgraduate              No
# 3636                     90        High School              No
# 3748                     60           Graduate              No
# ...
